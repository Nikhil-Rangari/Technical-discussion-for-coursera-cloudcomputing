# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil-Rangari/Technical-discussion-for-coursera-cloudcomputing/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def hello():
  return "hi"
hello()
# Out:
# 'hi'
